# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import api_key
from datetime import datetime
from pandas import Timestamp
import requests
import scipy.stats as stats

# %%
bigfoot_weather_df = pd.read_csv("Bigfoot Weather Data.csv")
bigfoot_weather_df.head()
# Out:
#    Unnamed: 0             county          state        date  latitude  \
# 0           1     Wyoming County  West Virginia  2005-12-03  37.58135
# 1           2     Windsor County        Vermont  2005-10-08  43.46540
# 2           3       Wythe County       Virginia  1984-04-08  37.22647
# 3           7  Washington County   Rhode Island  1974-09-20  41.45000
# 4          10     Washita County       Oklahoma  1973-09-28  35.30110
#
#    longitude  season  temperature_high  temperature_low  cloud_cover  \
# 0  -81.29745  Winter              37.8             21.6         66.7
# 1  -72.70510    Fall              64.3             45.9        100.0
# 2  -81.09017  Spring              59.0             37.0         76.2
# 3  -71.50000    Fall              78.2             65.9         96.7
# 4  -99.17020    Fall              72.6             47.6         14.0
#
#    precip_intensity  visibility                    conditions  wind_speed  \
# 0             0.204         9.3  Snow, Rain, Partially cloudy        17.1
# 1             3.208         5.0                Rain, Overcast         7.6
# 2             0.000        13.0              Partially cloudy        11.5
# 3             0.000         2.6                      Overcast        15.0
# 4             0.000        20.4                         Clear        12.7
#
#   Precip Intensity Groups Visibility Classification (mi)  \
# 0    moderate: 0.1 to 0.3           Clear: 6.21 to 12.43
# 1             violent: >2       Light Haze: 2.48 to 6.21
# 2         light: 0 to 0.1     Very Clear: 12.43 to 31.06
# 3         light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 4         light: 0 to 0.1     Very Clear: 12.43 to 31.06
#
#   Cloud Cover Classification (%)
# 0    Mostly Cloudy: 62.5 to 87.5
# 1   Cloudy/Overcast: 87.5 to 100
# 2    Mostly Cloudy: 62.5 to 87.5
# 3   Cloudy/Overcast: 87.5 to 100
# 4       Mostly Sunny: 6.25 to 25

# %%
dates = pd.DataFrame(bigfoot_weather_df['date'] + " 12:00:00")
dates_unix = pd.to_datetime(bigfoot_weather_df["date"])
unix = dates_unix.view("int64")
unix
bigfoot_weather_df["unix"] = unix
bigfoot_weather_df
# Out:
#       Unnamed: 0             county          state        date  latitude  \
# 0              1     Wyoming County  West Virginia  2005-12-03  37.58135
# 1              2     Windsor County        Vermont  2005-10-08  43.46540
# 2              3       Wythe County       Virginia  1984-04-08  37.22647
# 3              7  Washington County   Rhode Island  1974-09-20  41.45000
# 4             10     Washita County       Oklahoma  1973-09-28  35.30110
# ...          ...                ...            ...         ...       ...
# 2838        5069       Baker County        Florida  2006-04-12  30.43412
# 2839        5070     Alachua County        Florida  1963-09-15  29.67757
# 2840        5071     Alachua County        Florida  1985-09-29  29.77535
# 2841        5072     Alachua County        Florida  2000-06-13  29.58358
# 2842        5073     Alachua County        Florida  2012-10-09  29.74815
#
#       longitude   season  temperature_high  temperature_low  cloud_cover  \
# 0     -81.29745   Winter              37.8             21.6         66.7
# 1     -72.70510     Fall              64.3             45.9        100.0
# 2     -81.09017   Spring              59.0             37.0         76.2
# 3     -71.50000     Fall              78.2             65.9         96.7
# 4     -99.17020     Fall              72.6             47.6         14.0
# ...         ...      ...               ...              ...          ...
# 2838  -82.28943   Spring              75.7             58.0         53.0
# 2839  -82.35501  Unknown              80.0             64.9         85.2
# 2840  -82.36570     Fall              84.0             66.8         37.9
# 2841  -82.33316   Summer              93.5             69.2         33.5
# 2842  -82.44075     Fall              74.4             67.4         99.1
#
#       precip_intensity  visibility                    conditions  wind_speed  \
# 0                0.204         9.3  Snow, Rain, Partially cloudy        17.1
# 1                3.208         5.0                Rain, Overcast         7.6
# 2                0.000        13.0              Partially cloudy        11.5
# 3                0.000         2.6                      Overcast        15.0
# 4                0.000        20.4                         Clear        12.7
# ...                ...         ...                           ...         ...
# 2838             0.000         8.5              Partially cloudy        15.8
# 2839             0.078        13.6        Rain, Partially cloudy         9.2
# 2840             0.000         6.1              Partially cloudy        16.0
# 2841             0.000         8.5              Partially cloudy        11.5
# 2842             0.000         7.6                      Overcast         7.9
#
#      Precip Intensity Groups Visibility Classification (mi)  \
# 0       moderate: 0.1 to 0.3           Clear: 6.21 to 12.43
# 1                violent: >2       Light Haze: 2.48 to 6.21
# 2            light: 0 to 0.1     Very Clear: 12.43 to 31.06
# 3            light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 4            light: 0 to 0.1     Very Clear: 12.43 to 31.06
# ...                      ...                            ...
# 2838         light: 0 to 0.1           Clear: 6.21 to 12.43
# 2839         light: 0 to 0.1     Very Clear: 12.43 to 31.06
# 2840         light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 2841         light: 0 to 0.1           Clear: 6.21 to 12.43
# 2842         light: 0 to 0.1           Clear: 6.21 to 12.43
#
#        Cloud Cover Classification (%)                 unix
# 0         Mostly Cloudy: 62.5 to 87.5  1133568000000000000
# 1        Cloudy/Overcast: 87.5 to 100  1128729600000000000
# 2         Mostly Cloudy: 62.5 to 87.5   450230400000000000
# 3        Cloudy/Overcast: 87.5 to 100   148867200000000000
# 4            Mostly Sunny: 6.25 to 25   118022400000000000
# ...                               ...                  ...
# 2838  Partly Cloudy/Sunny: 25 to 62.5  1144800000000000000
# 2839      Mostly Cloudy: 62.5 to 87.5  -198720000000000000
# 2840  Partly Cloudy/Sunny: 25 to 62.5   496800000000000000
# 2841  Partly Cloudy/Sunny: 25 to 62.5   960854400000000000
# 2842     Cloudy/Overcast: 87.5 to 100  1349740800000000000
#
# [2843 rows x 18 columns]

# %%
temp_avgs = (bigfoot_weather_df['temperature_high'] + bigfoot_weather_df['temperature_low']) / 2
temp_avg = temp_avgs.mean()
bigfoot_weather_df["Temperature Average"] = temp_avgs
bigfoot_weather_df["Expected Temperature"] = temp_avg

# %%
precip_avgs = (bigfoot_weather_df['precip_intensity']).mean()
bigfoot_weather_df["Expected Precipitation"] = precip_avgs

# %%
cloudcover_avgs = (bigfoot_weather_df['cloud_cover']).mean()
bigfoot_weather_df["Expected Cloud Cover"] = cloudcover_avgs

# %%
visibility_avgs = (bigfoot_weather_df['visibility']).mean()
bigfoot_weather_df["Expected Visibility"] = visibility_avgs

bigfoot_weather_df.head(25)
# Out:
#     Unnamed: 0              county           state        date  latitude  \
# 0            1      Wyoming County   West Virginia  2005-12-03  37.58135
# 1            2      Windsor County         Vermont  2005-10-08  43.46540
# 2            3        Wythe County        Virginia  1984-04-08  37.22647
# 3            7   Washington County    Rhode Island  1974-09-20  41.45000
# 4           10      Washita County        Oklahoma  1973-09-28  35.30110
# 5           12  Westchester County        New York  2010-09-01  41.29873
# 6           14   Washington County            Ohio  1978-11-01  39.54739
# 7           15   Washington County            Ohio  1984-07-04  39.46019
# 8           16   Washington County            Ohio  1990-07-01  39.37310
# 9           17   Washington County            Ohio  2009-10-31  39.42635
# 10          19   Washington County    Rhode Island  1978-07-15  41.43200
# 11          20   Washington County    Rhode Island  2006-11-03  41.45960
# 12          21         York County  South Carolina  2022-07-05  35.05910
# 13          23       Wilson County       Tennessee  2008-10-27  35.99780
# 14          24       Wilson County       Tennessee  2010-07-16  36.25466
# 15          26         Wood County           Texas  2004-03-25  32.69028
# 16          28        Weber County            Utah  1962-05-01  41.50000
# 17          33        Weber County            Utah  2007-08-31  41.41125
# 18          34        Wythe County        Virginia  2003-10-23  37.00085
# 19          36        Wythe County        Virginia  2019-04-10  37.00480
# 20          37      Windsor County         Vermont  2015-05-24  43.43623
# 21          38       Yakima County      Washington  1941-10-15  46.24639
# 22          39       Yakima County      Washington  1996-08-30  46.71444
# 23          40       Yakima County      Washington  1996-11-01  46.56020
# 24          41       Yakima County      Washington  2000-06-13  46.87139
#
#     longitude  season  temperature_high  temperature_low  cloud_cover  ...  \
# 0   -81.29745  Winter              37.8             21.6         66.7  ...
# 1   -72.70510    Fall              64.3             45.9        100.0  ...
# 2   -81.09017  Spring              59.0             37.0         76.2  ...
# 3   -71.50000    Fall              78.2             65.9         96.7  ...
# 4   -99.17020    Fall              72.6             47.6         14.0  ...
# 5   -73.73717    Fall              90.6             67.3          9.0  ...
# 6   -81.39101  Winter              61.4             41.4         27.5  ...
# 7   -81.54855  Summer              79.9             70.1         91.6  ...
# 8   -81.65929  Summer              83.8             65.7         67.4  ...
# 9   -81.37085    Fall              69.0             48.8         81.6  ...
# 10  -71.65183  Summer              71.0             65.0        100.0  ...
# 11  -71.58906    Fall              45.8             29.7         21.9  ...
# 12  -81.11742  Summer              91.8             71.6         49.1  ...
# 13  -86.20110    Fall              56.7             40.2         56.1  ...
# 14  -86.15759  Summer              96.5             74.5         46.5  ...
# 15  -95.61056  Winter              80.0             61.1         94.6  ...
# 16 -111.75000  Spring              66.0             53.3         51.7  ...
# 17 -111.58330    Fall              85.4             69.1         33.5  ...
# 18  -80.87970    Fall              52.6             36.7         66.3  ...
# 19  -81.11751  Spring              70.3             44.2          8.2  ...
# 20  -72.43684  Spring              80.7             37.3         11.3  ...
# 21 -120.86810    Fall              80.7             37.3         11.3  ...
# 22 -120.66940  Summer              82.1             53.9          0.0  ...
# 23 -121.14580    Fall              51.2             23.1          0.0  ...
# 24 -121.29810  Summer              61.2             44.3         46.3  ...
#
#     wind_speed  Precip Intensity Groups Visibility Classification (mi)  \
# 0         17.1     moderate: 0.1 to 0.3           Clear: 6.21 to 12.43
# 1          7.6              violent: >2       Light Haze: 2.48 to 6.21
# 2         11.5          light: 0 to 0.1     Very Clear: 12.43 to 31.06
# 3         15.0          light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 4         12.7          light: 0 to 0.1     Very Clear: 12.43 to 31.06
# 5          6.3          light: 0 to 0.1           Clear: 6.21 to 12.43
# 6          8.5          light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 7         13.9          light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 8         15.8          light: 0 to 0.1       Light Haze: 2.48 to 6.21
# 9         18.3          heavy: 0.3 to 2           Clear: 6.21 to 12.43
# 10        13.9          heavy: 0.3 to 2           Clear: 6.21 to 12.43
# 11         7.7          light: 0 to 0.1           Clear: 6.21 to 12.43
# 12        14.2     moderate: 0.1 to 0.3           Clear: 6.21 to 12.43
# 13        20.8          light: 0 to 0.1           Clear: 6.21 to 12.43
# 14        11.4     moderate: 0.1 to 0.3           Clear: 6.21 to 12.43
# 15        18.3          light: 0 to 0.1           Clear: 6.21 to 12.43
# 16        10.0          light: 0 to 0.1           Clear: 6.21 to 12.43
# 17        11.0          light: 0 to 0.1           Clear: 6.21 to 12.43
# 18        14.6          light: 0 to 0.1           Clear: 6.21 to 12.43
# 19        11.0          light: 0 to 0.1           Clear: 6.21 to 12.43
# 20        15.5          light: 0 to 0.1           Clear: 6.21 to 12.43
# 21        15.5          light: 0 to 0.1           Clear: 6.21 to 12.43
# 22        18.3          light: 0 to 0.1           Clear: 6.21 to 12.43
# 23         8.1          light: 0 to 0.1           Clear: 6.21 to 12.43
# 24        14.9     moderate: 0.1 to 0.3           Clear: 6.21 to 12.43
#
#      Cloud Cover Classification (%)                 unix Temperature Average  \
# 0       Mostly Cloudy: 62.5 to 87.5  1133568000000000000               29.70
# 1      Cloudy/Overcast: 87.5 to 100  1128729600000000000               55.10
# 2       Mostly Cloudy: 62.5 to 87.5   450230400000000000               48.00
# 3      Cloudy/Overcast: 87.5 to 100   148867200000000000               72.05
# 4          Mostly Sunny: 6.25 to 25   118022400000000000               60.10
# 5          Mostly Sunny: 6.25 to 25  1283299200000000000               78.95
# 6   Partly Cloudy/Sunny: 25 to 62.5   278726400000000000               51.40
# 7      Cloudy/Overcast: 87.5 to 100   457747200000000000               75.00
# 8       Mostly Cloudy: 62.5 to 87.5   646790400000000000               74.75
# 9       Mostly Cloudy: 62.5 to 87.5  1256947200000000000               58.90
# 10     Cloudy/Overcast: 87.5 to 100   269308800000000000               68.00
# 11         Mostly Sunny: 6.25 to 25  1162512000000000000               37.75
# 12  Partly Cloudy/Sunny: 25 to 62.5  1656979200000000000               81.70
# 13  Partly Cloudy/Sunny: 25 to 62.5  1225065600000000000               48.45
# 14  Partly Cloudy/Sunny: 25 to 62.5  1279238400000000000               85.50
# 15     Cloudy/Overcast: 87.5 to 100  1080172800000000000               70.55
# 16  Partly Cloudy/Sunny: 25 to 62.5  -242092800000000000               59.65
# 17  Partly Cloudy/Sunny: 25 to 62.5  1188518400000000000               77.25
# 18      Mostly Cloudy: 62.5 to 87.5  1066867200000000000               44.65
# 19         Mostly Sunny: 6.25 to 25  1554854400000000000               57.25
# 20         Mostly Sunny: 6.25 to 25  1432425600000000000               59.00
# 21         Mostly Sunny: 6.25 to 25  -890352000000000000               59.00
# 22                 Sunny: 0 to 6.25   841363200000000000               68.00
# 23                 Sunny: 0 to 6.25   846806400000000000               37.15
# 24  Partly Cloudy/Sunny: 25 to 62.5   960854400000000000               52.75
#
#    Expected Temperature  Expected Precipitation  Expected Cloud Cover  \
# 0             59.071456                0.093595             45.721702
# 1             59.071456                0.093595             45.721702
# 2             59.071456                0.093595             45.721702
# 3             59.071456                0.093595             45.721702
# 4             59.071456                0.093595             45.721702
# 5             59.071456                0.093595             45.721702
# 6             59.071456                0.093595             45.721702
# 7             59.071456                0.093595             45.721702
# 8             59.071456                0.093595             45.721702
# 9             59.071456                0.093595             45.721702
# 10            59.071456                0.093595             45.721702
# 11            59.071456                0.093595             45.721702
# 12            59.071456                0.093595             45.721702
# 13            59.071456                0.093595             45.721702
# 14            59.071456                0.093595             45.721702
# 15            59.071456                0.093595             45.721702
# 16            59.071456                0.093595             45.721702
# 17            59.071456                0.093595             45.721702
# 18            59.071456                0.093595             45.721702
# 19            59.071456                0.093595             45.721702
# 20            59.071456                0.093595             45.721702
# 21            59.071456                0.093595             45.721702
# 22            59.071456                0.093595             45.721702
# 23            59.071456                0.093595             45.721702
# 24            59.071456                0.093595             45.721702
#
#     Expected Visibility
# 0              9.977664
# 1              9.977664
# 2              9.977664
# 3              9.977664
# 4              9.977664
# 5              9.977664
# 6              9.977664
# 7              9.977664
# 8              9.977664
# 9              9.977664
# 10             9.977664
# 11             9.977664
# 12             9.977664
# 13             9.977664
# 14             9.977664
# 15             9.977664
# 16             9.977664
# 17             9.977664
# 18             9.977664
# 19             9.977664
# 20             9.977664
# 21             9.977664
# 22             9.977664
# 23             9.977664
# 24             9.977664
#
# [25 rows x 23 columns]

# %%
precip_groups = bigfoot_weather_df.groupby('Precip Intensity Groups')
precip_counts = precip_groups['Precip Intensity Groups'].count()

precip_chart = precip_counts.plot(kind="bar", title="Precip Intensity by Classification")

plt.show()

# %%
# The degree of freedom is 4-1 = 3
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95.
critical_value = stats.chi2.ppf(q = 0.95, df = 3)

#Display the critical value
critical_value
# Out:
# 7.814727903251179

# %%
stats.chisquare(bigfoot_weather_df['precip_intensity'], bigfoot_weather_df['Expected Precipitation'])
# Out:
# Power_divergenceResult(statistic=2569.9207864932946, pvalue=0.9999011697690071)

# %%
visibility_groups = bigfoot_weather_df.groupby('Visibility Classification (mi)')
visibility_counts = visibility_groups['Visibility Classification (mi)'].count()

visibility_chart = visibility_counts.plot(kind="bar", title="Visibility by Classification")

plt.show()

# %%
# The degree of freedom is 7-1 = 6
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95.
critical_value = stats.chi2.ppf(q = 0.95, df = 6)

#Display the critical value
critical_value
# Out:
# 12.591587243743977

# %%
stats.chisquare(bigfoot_weather_df['visibility'], bigfoot_weather_df['Expected Visibility'])
# Out:
# Power_divergenceResult(statistic=6520.128241411463, pvalue=4.730756700723386e-289)

# %%
cloudcover_groups = bigfoot_weather_df.groupby('Cloud Cover Classification (%)')
cloudcover_counts = cloudcover_groups['Cloud Cover Classification (%)'].count()

cloudcover_chart = cloudcover_counts.plot(kind="bar", title="Cloud Cover by Classification")

plt.show()

# %%
# The degree of freedom is 5-1 = 4
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95.
critical_value = stats.chi2.ppf(q = 0.95, df = 4)

#Display the critical value
critical_value
# Out:
# 9.487729036781154

# %%
stats.chisquare(bigfoot_weather_df['cloud_cover'], bigfoot_weather_df['Expected Cloud Cover'])
# Out:
# Power_divergenceResult(statistic=67535.27683903284, pvalue=0.0)

# %%
bigfoot_reduced = pd.DataFrame(bigfoot_weather_df[["state", "latitude","season",
                                                  "Temperature Average",
                                                  "cloud_cover", "Cloud Cover Classification (%)",
                                                   "visibility", "Visibility Classification (mi)",
                                                   "precip_intensity", "Precip Intensity Groups"
                                                  ]])
bigfoot_summer = bigfoot_reduced.loc[(bigfoot_reduced["state"] == "Washington") &
                                    (bigfoot_reduced["season"] == "Summer"), :]
bigfoot_summer
# Out:
#            state  latitude  season  Temperature Average  cloud_cover  \
# 22    Washington  46.71444  Summer                68.00          0.0
# 24    Washington  46.87139  Summer                52.75         46.3
# 25    Washington  46.87330  Summer                71.05          0.0
# 26    Washington  46.82167  Summer                64.50         17.5
# 29    Washington  46.49840  Summer                74.80          0.1
# ...          ...       ...     ...                  ...          ...
# 1211  Washington  46.92694  Summer                51.05         52.9
# 1212  Washington  46.98621  Summer                36.05         75.8
# 1214  Washington  47.23310  Summer                59.15         98.6
# 1215  Washington  47.50319  Summer                64.10         45.9
# 1216  Washington  46.96189  Summer                57.70         73.3
#
#        Cloud Cover Classification (%)  visibility  \
# 22                   Sunny: 0 to 6.25         9.9
# 24    Partly Cloudy/Sunny: 25 to 62.5         6.6
# 25                   Sunny: 0 to 6.25         8.9
# 26           Mostly Sunny: 6.25 to 25         9.5
# 29                   Sunny: 0 to 6.25        10.0
# ...                               ...         ...
# 1211  Partly Cloudy/Sunny: 25 to 62.5         9.5
# 1212      Mostly Cloudy: 62.5 to 87.5         8.7
# 1214     Cloudy/Overcast: 87.5 to 100         6.7
# 1215  Partly Cloudy/Sunny: 25 to 62.5         9.2
# 1216      Mostly Cloudy: 62.5 to 87.5         9.2
#
#      Visibility Classification (mi)  precip_intensity Precip Intensity Groups
# 22             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 24             Clear: 6.21 to 12.43             0.123    moderate: 0.1 to 0.3
# 25             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 26             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 29             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# ...                             ...               ...                     ...
# 1211           Clear: 6.21 to 12.43             0.453         heavy: 0.3 to 2
# 1212           Clear: 6.21 to 12.43             0.216    moderate: 0.1 to 0.3
# 1214           Clear: 6.21 to 12.43             0.171    moderate: 0.1 to 0.3
# 1215           Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 1216           Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
#
# [164 rows x 10 columns]

# %%
# Using Average temp in Seattle from NOAA of 60.5F during June

bigfoot_summer["Expected Temperature"] = 60.5

# Finding "expected visibility"
bigfoot_summer["Expected Visibility"] = bigfoot_summer["visibility"].mean()

bigfoot_summer["Expected Cloud Cover"] = bigfoot_summer["cloud_cover"].mean()

bigfoot_summer["Expected Precipitation Intensity"] = bigfoot_summer["precip_intensity"].mean()

bigfoot_summer
# Out:
# /Users/matthewtao/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/matthewtao/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/matthewtao/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/matthewtao/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#            state  latitude  season  Temperature Average  cloud_cover  \
# 22    Washington  46.71444  Summer                68.00          0.0
# 24    Washington  46.87139  Summer                52.75         46.3
# 25    Washington  46.87330  Summer                71.05          0.0
# 26    Washington  46.82167  Summer                64.50         17.5
# 29    Washington  46.49840  Summer                74.80          0.1
# ...          ...       ...     ...                  ...          ...
# 1211  Washington  46.92694  Summer                51.05         52.9
# 1212  Washington  46.98621  Summer                36.05         75.8
# 1214  Washington  47.23310  Summer                59.15         98.6
# 1215  Washington  47.50319  Summer                64.10         45.9
# 1216  Washington  46.96189  Summer                57.70         73.3
#
#        Cloud Cover Classification (%)  visibility  \
# 22                   Sunny: 0 to 6.25         9.9
# 24    Partly Cloudy/Sunny: 25 to 62.5         6.6
# 25                   Sunny: 0 to 6.25         8.9
# 26           Mostly Sunny: 6.25 to 25         9.5
# 29                   Sunny: 0 to 6.25        10.0
# ...                               ...         ...
# 1211  Partly Cloudy/Sunny: 25 to 62.5         9.5
# 1212      Mostly Cloudy: 62.5 to 87.5         8.7
# 1214     Cloudy/Overcast: 87.5 to 100         6.7
# 1215  Partly Cloudy/Sunny: 25 to 62.5         9.2
# 1216      Mostly Cloudy: 62.5 to 87.5         9.2
#
#      Visibility Classification (mi)  precip_intensity Precip Intensity Groups  \
# 22             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 24             Clear: 6.21 to 12.43             0.123    moderate: 0.1 to 0.3
# 25             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 26             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 29             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# ...                             ...               ...                     ...
# 1211           Clear: 6.21 to 12.43             0.453         heavy: 0.3 to 2
# 1212           Clear: 6.21 to 12.43             0.216    moderate: 0.1 to 0.3
# 1214           Clear: 6.21 to 12.43             0.171    moderate: 0.1 to 0.3
# 1215           Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 1216           Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
#
#       Expected Temperature  Expected Visibility  Expected Cloud Cover  \
# 22                    60.5            12.216463             44.860976
# 24                    60.5            12.216463             44.860976
# 25                    60.5            12.216463             44.860976
# 26                    60.5            12.216463             44.860976
# 29                    60.5            12.216463             44.860976
# ...                    ...                  ...                   ...
# 1211                  60.5            12.216463             44.860976
# 1212                  60.5            12.216463             44.860976
# 1214                  60.5            12.216463             44.860976
# 1215                  60.5            12.216463             44.860976
# 1216                  60.5            12.216463             44.860976
#
#       Expected Precipitation Intensity
# 22                             0.05247
# 24                             0.05247
# 25                             0.05247
# 26                             0.05247
# 29                             0.05247
# ...                                ...
# 1211                           0.05247
# 1212                           0.05247
# 1214                           0.05247
# 1215                           0.05247
# 1216                           0.05247
#
# [164 rows x 14 columns]

# %%
min(bigfoot_summer["Temperature Average"]), max(bigfoot_summer["Temperature Average"])
# Out:
# (27.35, 81.05)

# %%
# Bins for temperature
bins = [0, 32, 50, 62.5, 75, 87.5]

# Create labels for these bins
group_labels = ["Freezing: 0 to 32F", "Cold: 32F to 50F", "Mild: 50F to 62.5", "Warm: 62.5F to 75F", "Hot: 75F to 100F"
               ]


# Place the data series into a new column inside of the DataFrame
bigfoot_summer["Temperature Classifications"] = pd.cut(bigfoot_summer["Temperature Average"], bins, labels=group_labels)

bigfoot_summer
# Out:
# /Users/matthewtao/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#            state  latitude  season  Temperature Average  cloud_cover  \
# 22    Washington  46.71444  Summer                68.00          0.0
# 24    Washington  46.87139  Summer                52.75         46.3
# 25    Washington  46.87330  Summer                71.05          0.0
# 26    Washington  46.82167  Summer                64.50         17.5
# 29    Washington  46.49840  Summer                74.80          0.1
# ...          ...       ...     ...                  ...          ...
# 1211  Washington  46.92694  Summer                51.05         52.9
# 1212  Washington  46.98621  Summer                36.05         75.8
# 1214  Washington  47.23310  Summer                59.15         98.6
# 1215  Washington  47.50319  Summer                64.10         45.9
# 1216  Washington  46.96189  Summer                57.70         73.3
#
#        Cloud Cover Classification (%)  visibility  \
# 22                   Sunny: 0 to 6.25         9.9
# 24    Partly Cloudy/Sunny: 25 to 62.5         6.6
# 25                   Sunny: 0 to 6.25         8.9
# 26           Mostly Sunny: 6.25 to 25         9.5
# 29                   Sunny: 0 to 6.25        10.0
# ...                               ...         ...
# 1211  Partly Cloudy/Sunny: 25 to 62.5         9.5
# 1212      Mostly Cloudy: 62.5 to 87.5         8.7
# 1214     Cloudy/Overcast: 87.5 to 100         6.7
# 1215  Partly Cloudy/Sunny: 25 to 62.5         9.2
# 1216      Mostly Cloudy: 62.5 to 87.5         9.2
#
#      Visibility Classification (mi)  precip_intensity Precip Intensity Groups  \
# 22             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 24             Clear: 6.21 to 12.43             0.123    moderate: 0.1 to 0.3
# 25             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 26             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 29             Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# ...                             ...               ...                     ...
# 1211           Clear: 6.21 to 12.43             0.453         heavy: 0.3 to 2
# 1212           Clear: 6.21 to 12.43             0.216    moderate: 0.1 to 0.3
# 1214           Clear: 6.21 to 12.43             0.171    moderate: 0.1 to 0.3
# 1215           Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
# 1216           Clear: 6.21 to 12.43             0.000         light: 0 to 0.1
#
#       Expected Temperature  Expected Visibility  Expected Cloud Cover  \
# 22                    60.5            12.216463             44.860976
# 24                    60.5            12.216463             44.860976
# 25                    60.5            12.216463             44.860976
# 26                    60.5            12.216463             44.860976
# 29                    60.5            12.216463             44.860976
# ...                    ...                  ...                   ...
# 1211                  60.5            12.216463             44.860976
# 1212                  60.5            12.216463             44.860976
# 1214                  60.5            12.216463             44.860976
# 1215                  60.5            12.216463             44.860976
# 1216                  60.5            12.216463             44.860976
#
#       Expected Precipitation Intensity Temperature Classifications
# 22                             0.05247          Warm: 62.5F to 75F
# 24                             0.05247           Mild: 50F to 62.5
# 25                             0.05247          Warm: 62.5F to 75F
# 26                             0.05247          Warm: 62.5F to 75F
# 29                             0.05247          Warm: 62.5F to 75F
# ...                                ...                         ...
# 1211                           0.05247           Mild: 50F to 62.5
# 1212                           0.05247            Cold: 32F to 50F
# 1214                           0.05247           Mild: 50F to 62.5
# 1215                           0.05247          Warm: 62.5F to 75F
# 1216                           0.05247           Mild: 50F to 62.5
#
# [164 rows x 15 columns]

# %%
bigfoot_washington_summer = bigfoot_summer[["state", "latitude", "season", 
                                           "Temperature Average", "Expected Temperature", "Temperature Classifications",
                                           "cloud_cover", "Expected Cloud Cover", "Cloud Cover Classification (%)",
                                           "visibility", "Expected Visibility", "Visibility Classification (mi)",
                                           "precip_intensity", "Expected Precipitation Intensity", "Precip Intensity Groups"
]]
bigfoot_washington_summer
# Out:
#            state  latitude  season  Temperature Average  Expected Temperature  \
# 22    Washington  46.71444  Summer                68.00                  60.5
# 24    Washington  46.87139  Summer                52.75                  60.5
# 25    Washington  46.87330  Summer                71.05                  60.5
# 26    Washington  46.82167  Summer                64.50                  60.5
# 29    Washington  46.49840  Summer                74.80                  60.5
# ...          ...       ...     ...                  ...                   ...
# 1211  Washington  46.92694  Summer                51.05                  60.5
# 1212  Washington  46.98621  Summer                36.05                  60.5
# 1214  Washington  47.23310  Summer                59.15                  60.5
# 1215  Washington  47.50319  Summer                64.10                  60.5
# 1216  Washington  46.96189  Summer                57.70                  60.5
#
#      Temperature Classifications  cloud_cover  Expected Cloud Cover  \
# 22            Warm: 62.5F to 75F          0.0             44.860976
# 24             Mild: 50F to 62.5         46.3             44.860976
# 25            Warm: 62.5F to 75F          0.0             44.860976
# 26            Warm: 62.5F to 75F         17.5             44.860976
# 29            Warm: 62.5F to 75F          0.1             44.860976
# ...                          ...          ...                   ...
# 1211           Mild: 50F to 62.5         52.9             44.860976
# 1212            Cold: 32F to 50F         75.8             44.860976
# 1214           Mild: 50F to 62.5         98.6             44.860976
# 1215          Warm: 62.5F to 75F         45.9             44.860976
# 1216           Mild: 50F to 62.5         73.3             44.860976
#
#        Cloud Cover Classification (%)  visibility  Expected Visibility  \
# 22                   Sunny: 0 to 6.25         9.9            12.216463
# 24    Partly Cloudy/Sunny: 25 to 62.5         6.6            12.216463
# 25                   Sunny: 0 to 6.25         8.9            12.216463
# 26           Mostly Sunny: 6.25 to 25         9.5            12.216463
# 29                   Sunny: 0 to 6.25        10.0            12.216463
# ...                               ...         ...                  ...
# 1211  Partly Cloudy/Sunny: 25 to 62.5         9.5            12.216463
# 1212      Mostly Cloudy: 62.5 to 87.5         8.7            12.216463
# 1214     Cloudy/Overcast: 87.5 to 100         6.7            12.216463
# 1215  Partly Cloudy/Sunny: 25 to 62.5         9.2            12.216463
# 1216      Mostly Cloudy: 62.5 to 87.5         9.2            12.216463
#
#      Visibility Classification (mi)  precip_intensity  \
# 22             Clear: 6.21 to 12.43             0.000
# 24             Clear: 6.21 to 12.43             0.123
# 25             Clear: 6.21 to 12.43             0.000
# 26             Clear: 6.21 to 12.43             0.000
# 29             Clear: 6.21 to 12.43             0.000
# ...                             ...               ...
# 1211           Clear: 6.21 to 12.43             0.453
# 1212           Clear: 6.21 to 12.43             0.216
# 1214           Clear: 6.21 to 12.43             0.171
# 1215           Clear: 6.21 to 12.43             0.000
# 1216           Clear: 6.21 to 12.43             0.000
#
#       Expected Precipitation Intensity Precip Intensity Groups
# 22                             0.05247         light: 0 to 0.1
# 24                             0.05247    moderate: 0.1 to 0.3
# 25                             0.05247         light: 0 to 0.1
# 26                             0.05247         light: 0 to 0.1
# 29                             0.05247         light: 0 to 0.1
# ...                                ...                     ...
# 1211                           0.05247         heavy: 0.3 to 2
# 1212                           0.05247    moderate: 0.1 to 0.3
# 1214                           0.05247    moderate: 0.1 to 0.3
# 1215                           0.05247         light: 0 to 0.1
# 1216                           0.05247         light: 0 to 0.1
#
# [164 rows x 15 columns]

# %%
bigfoot_washington_summer.to_csv("Bigfoot_Washington_Summer_df.csv")

# %%
# This line down was me experimenting how to pull historical weather data from OpenWeatherMap. Unfortunately it is not free...

lat = 37.58135
lon = -81.29745
dt = 1133568000000000000

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/onecall/timemachine?" 
units = "imperial"

# Build partial query URL
query_url = f"{url}lat={lat}&lon={lon}&dt={date}&appid=1105a825f3c3392d6506e6f39616d970&units={units}"

# %%
response = requests.get(query_url).json()
response
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}
